# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
ipl= pd.read_csv("ipl2022.csv")

# %%
ipl.head(3)
# Out:
#    Unnamed: 0           Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0           0      Rashid Khan  Draft Pick       BOWLER             15.0
# 1           1    Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           2  Lockie Ferguson        2 Cr       BOWLER             10.0
#
#    Cost IN $ (000) 2021 Squad            Team
# 0           1950.0        SRH  Gujarat Titans
# 1           1950.0         MI  Gujarat Titans
# 2           1300.0        KKR  Gujarat Titans

# %%
ipl.tail(3)
# Out:
#      Unnamed: 0                  Player Base Price         TYPE  \
# 630         630  Nivethan Radhakrishnan    20 Lakh       BOWLER
# 631         631            Lance Morris    20 Lakh       BOWLER
# 632         632            Aaron Hardie    20 Lakh  ALL-ROUNDER
#
#      COST IN ₹ (CR.)  Cost IN $ (000) 2021 Squad    Team
# 630              NaN              NaN        NaN  Unsold
# 631              NaN              NaN        NaN  Unsold
# 632              NaN              NaN        NaN  Unsold

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 633 entries, 0 to 632
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       633 non-null    int64
#  1   Player           633 non-null    object
#  2   Base Price       633 non-null    object
#  3   TYPE             633 non-null    object
#  4   COST IN ₹ (CR.)  237 non-null    float64
#  5   Cost IN $ (000)  237 non-null    float64
#  6   2021 Squad       199 non-null    object
#  7   Team             633 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 39.7+ KB

# %%
ipl.shape
# Out:
# (633, 8)

# %%
ipl.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Base Price', 'TYPE', 'COST IN ₹ (CR.)',
#        'Cost IN $ (000)', '2021 Squad', 'Team'],
#       dtype='object')

# %%
ipl.head(15)
# Out:
#     Unnamed: 0               Player  Base Price          TYPE  \
# 0            0          Rashid Khan  Draft Pick        BOWLER
# 1            1        Hardik Pandya  Draft Pick   ALL-ROUNDER
# 2            2      Lockie Ferguson        2 Cr        BOWLER
# 3            3        Rahul Tewatia     40 Lakh   ALL-ROUNDER
# 4            4         Shubman Gill  Draft Pick        BATTER
# 5            5       Mohammad Shami        2 Cr        BOWLER
# 6            6           Yash Dayal     20 Lakh        BOWLER
# 7            7         David Miller        1 Cr        BATTER
# 8            8       R. Sai Kishore     20 Lakh        BOWLER
# 9            9  Abhinav Sadarangani     20 Lakh        BATTER
# 10          10         Matthew Wade        2 Cr  WICKETKEEPER
# 11          11       Alzarri Joseph     75 Lakh        BOWLER
# 12          12            Jason Roy        2 Cr        BATTER
# 13          13      Wriddhiman Saha        1 Cr  WICKETKEEPER
# 14          14         Jayant Yadav        1 Cr   ALL-ROUNDER
#
#     COST IN ₹ (CR.)  Cost IN $ (000) 2021 Squad            Team
# 0             15.00           1950.0        SRH  Gujarat Titans
# 1             15.00           1950.0         MI  Gujarat Titans
# 2             10.00           1300.0        KKR  Gujarat Titans
# 3              9.00           1170.0         RR  Gujarat Titans
# 4              8.00           1040.0        KKR  Gujarat Titans
# 5              6.25            812.5       PBKS  Gujarat Titans
# 6              3.20            416.0        NaN  Gujarat Titans
# 7              3.00            390.0         RR  Gujarat Titans
# 8              3.00            390.0        CSK  Gujarat Titans
# 9              2.60            338.0        NaN  Gujarat Titans
# 10             2.40            312.0        NaN  Gujarat Titans
# 11             2.40            312.0        NaN  Gujarat Titans
# 12             2.00            260.0        SRH  Gujarat Titans
# 13             1.90            247.0        SRH  Gujarat Titans
# 14             1.70            221.0         MI  Gujarat Titans

# %%
#drop the 1st columns becouse its not useful
ipl.drop('Unnamed: 0',axis=1,inplace=True)

# %%
ipl.head()
# Out:
#             Player  Base Price         TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0      Rashid Khan  Draft Pick       BOWLER             15.0           1950.0
# 1    Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0           1950.0
# 2  Lockie Ferguson        2 Cr       BOWLER             10.0           1300.0
# 3    Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0           1170.0
# 4     Shubman Gill  Draft Pick       BATTER              8.0           1040.0
#
#   2021 Squad            Team
# 0        SRH  Gujarat Titans
# 1         MI  Gujarat Titans
# 2        KKR  Gujarat Titans
# 3         RR  Gujarat Titans
# 4        KKR  Gujarat Titans

# %%
ipl.columns
# Out:
# Index(['Player', 'Base Price', 'TYPE', 'COST IN ₹ (CR.)', 'Cost IN $ (000)',
#        '2021 Squad', 'Team'],
#       dtype='object')

# %%
ipl.head()
# Out:
#             Player  Base Price         TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0      Rashid Khan  Draft Pick       BOWLER             15.0           1950.0
# 1    Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0           1950.0
# 2  Lockie Ferguson        2 Cr       BOWLER             10.0           1300.0
# 3    Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0           1170.0
# 4     Shubman Gill  Draft Pick       BATTER              8.0           1040.0
#
#   2021 Squad            Team
# 0        SRH  Gujarat Titans
# 1         MI  Gujarat Titans
# 2        KKR  Gujarat Titans
# 3         RR  Gujarat Titans
# 4        KKR  Gujarat Titans

# %%
#find the null values
ipl.isnull().sum()
# Out:
# Player               0
# Base Price           0
# TYPE                 0
# COST IN ₹ (CR.)    396
# Cost IN $ (000)    396
# 2021 Squad         434
# Team                 0
# dtype: int64

# %%
#now check how many rows are null in Cost IN $ (000)
ipl[ipl['Cost IN $ (000)'].isnull()]
# Out:
#                      Player Base Price         TYPE  COST IN ₹ (CR.)  \
# 237            Suresh Raina       2 Cr       BATTER              NaN
# 238             Steve Smith       2 Cr       BATTER              NaN
# 239         Shakib Al Hasan       2 Cr  ALL-ROUNDER              NaN
# 240             Amit Mishra     1.5 Cr       BOWLER              NaN
# 241             Adil Rashid       2 Cr       BOWLER              NaN
# ..                      ...        ...          ...              ...
# 628            Sairaj Patil    20 Lakh       BATTER              NaN
# 629              Monu Singh    20 Lakh       BOWLER              NaN
# 630  Nivethan Radhakrishnan    20 Lakh       BOWLER              NaN
# 631            Lance Morris    20 Lakh       BOWLER              NaN
# 632            Aaron Hardie    20 Lakh  ALL-ROUNDER              NaN
#
#      Cost IN $ (000) 2021 Squad    Team
# 237              NaN        CSK  Unsold
# 238              NaN         DC  Unsold
# 239              NaN        KKR  Unsold
# 240              NaN         DC  Unsold
# 241              NaN       PBKS  Unsold
# ..               ...        ...     ...
# 628              NaN        NaN  Unsold
# 629              NaN        NaN  Unsold
# 630              NaN        NaN  Unsold
# 631              NaN        NaN  Unsold
# 632              NaN        NaN  Unsold
#
# [396 rows x 7 columns]

# %%
#now fill the null values in 0
ipl['COST IN ₹ (CR.)']=ipl['COST IN ₹ (CR.)'].fillna(0)
ipl['Cost IN $ (000)']=ipl['Cost IN $ (000)'].fillna(0)

# %%
ipl[ipl['Cost IN $ (000)'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Player, Base Price, TYPE, COST IN ₹ (CR.), Cost IN $ (000), 2021 Squad, Team]
# Index: []

# %%
ipl.isnull().sum()
# Out:
# Player               0
# Base Price           0
# TYPE                 0
# COST IN ₹ (CR.)      0
# Cost IN $ (000)      0
# 2021 Squad         434
# Team                 0
# dtype: int64

# %%
ipl.head()
# Out:
#             Player  Base Price         TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0      Rashid Khan  Draft Pick       BOWLER             15.0           1950.0
# 1    Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0           1950.0
# 2  Lockie Ferguson        2 Cr       BOWLER             10.0           1300.0
# 3    Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0           1170.0
# 4     Shubman Gill  Draft Pick       BATTER              8.0           1040.0
#
#   2021 Squad            Team
# 0        SRH  Gujarat Titans
# 1         MI  Gujarat Titans
# 2        KKR  Gujarat Titans
# 3         RR  Gujarat Titans
# 4        KKR  Gujarat Titans

# %%
ipl.tail()
# Out:
#                      Player Base Price         TYPE  COST IN ₹ (CR.)  \
# 628            Sairaj Patil    20 Lakh       BATTER              0.0
# 629              Monu Singh    20 Lakh       BOWLER              0.0
# 630  Nivethan Radhakrishnan    20 Lakh       BOWLER              0.0
# 631            Lance Morris    20 Lakh       BOWLER              0.0
# 632            Aaron Hardie    20 Lakh  ALL-ROUNDER              0.0
#
#      Cost IN $ (000) 2021 Squad    Team
# 628              0.0        NaN  Unsold
# 629              0.0        NaN  Unsold
# 630              0.0        NaN  Unsold
# 631              0.0        NaN  Unsold
# 632              0.0        NaN  Unsold

# %%
ipl.shape
# Out:
# (633, 7)

# %%
ipl.isnull().sum()
# Out:
# Player             0
# Base Price         0
# TYPE               0
# COST IN ₹ (CR.)    0
# Cost IN $ (000)    0
# 2021 Squad         0
# Team               0
# dtype: int64

# %%
ipl[ipl['2021 Squad'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Player, Base Price, TYPE, COST IN ₹ (CR.), Cost IN $ (000), 2021 Squad, Team]
# Index: []

# %%
ipl['2021 Squad']= ipl['2021 Squad'].fillna('Not Participate')

# %%
ipl.isnull().sum()
# Out:
# Player             0
# Base Price         0
# TYPE               0
# COST IN ₹ (CR.)    0
# Cost IN $ (000)    0
# 2021 Squad         0
# Team               0
# dtype: int64

# %%
#not no any null values

# %%
teams= ipl[ipl['COST IN ₹ (CR.)']>0]['Team'].unique()

# %%
teams
# Out:
# array(['Gujarat Titans', 'Chennai Super Kings', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Punjab Kings', 'Lucknow Super Giants',
#        'Mumbai Indians', 'Royal Challengers Bangalore',
#        'Rajasthan Royals', 'Sunrisers Hyderabad'], dtype=object)

# %%
#create new columns
ipl['Status']= ipl['Team'].replace(teams,'sold')

# %%
ipl.isnull().sum()
# Out:
# Player             0
# Base Price         0
# TYPE               0
# COST IN ₹ (CR.)    0
# Cost IN $ (000)    0
# 2021 Squad         0
# Team               0
# Status             0
# dtype: int64

# %%
ipl
# Out:
#                      Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0               Rashid Khan  Draft Pick       BOWLER             15.0
# 1             Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           Lockie Ferguson        2 Cr       BOWLER             10.0
# 3             Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4              Shubman Gill  Draft Pick       BATTER              8.0
# ..                      ...         ...          ...              ...
# 628            Sairaj Patil     20 Lakh       BATTER              0.0
# 629              Monu Singh     20 Lakh       BOWLER              0.0
# 630  Nivethan Radhakrishnan     20 Lakh       BOWLER              0.0
# 631            Lance Morris     20 Lakh       BOWLER              0.0
# 632            Aaron Hardie     20 Lakh  ALL-ROUNDER              0.0
#
#      Cost IN $ (000)       2021 Squad            Team  Status
# 0             1950.0              SRH  Gujarat Titans    sold
# 1             1950.0               MI  Gujarat Titans    sold
# 2             1300.0              KKR  Gujarat Titans    sold
# 3             1170.0               RR  Gujarat Titans    sold
# 4             1040.0              KKR  Gujarat Titans    sold
# ..               ...              ...             ...     ...
# 628              0.0  Not Participate          Unsold  Unsold
# 629              0.0  Not Participate          Unsold  Unsold
# 630              0.0  Not Participate          Unsold  Unsold
# 631              0.0  Not Participate          Unsold  Unsold
# 632              0.0  Not Participate          Unsold  Unsold
#
# [633 rows x 8 columns]

# %%
#find Duplicate Player and find Diffrent one
ipl[ipl['Player'].duplicated(keep=False)]
# Out:
#             Player Base Price         TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 62     Lalit Yadav    20 Lakh  ALL-ROUNDER             0.65             84.5
# 240    Amit Mishra     1.5 Cr       BOWLER             0.00              0.0
# 499    Amit Mishra    20 Lakh       BOWLER             0.00              0.0
# 518  Shivam Sharma    20 Lakh  ALL-ROUNDER             0.00              0.0
# 530    Lalit Yadav    20 Lakh       BOWLER             0.00              0.0
# 537  Shubham Singh    20 Lakh  ALL-ROUNDER             0.00              0.0
# 544  Shubham Singh    20 Lakh       BOWLER             0.00              0.0
# 569  Shivam Sharma    20 Lakh  ALL-ROUNDER             0.00              0.0
#
#           2021 Squad            Team  Status
# 62                DC  Delhi Capitals    sold
# 240               DC          Unsold  Unsold
# 499  Not Participate          Unsold  Unsold
# 518  Not Participate          Unsold  Unsold
# 530  Not Participate          Unsold  Unsold
# 537  Not Participate          Unsold  Unsold
# 544  Not Participate          Unsold  Unsold
# 569  Not Participate          Unsold  Unsold

# %%
#how many players in participate in 2022 auction
ipl.shape[0]
# Out:
# 633

# %%
#how many types of players in participate in 2022 auction

types= ipl["TYPE"].value_counts()
types
# Out:
# ALL-ROUNDER     242
# BOWLER          215
# BATTER          112
# WICKETKEEPER     64
# Name: TYPE, dtype: int64

# %%
types.reset_index()
# Out:
#           index  TYPE
# 0   ALL-ROUNDER   242
# 1        BOWLER   215
# 2        BATTER   112
# 3  WICKETKEEPER    64

# %%
plt.pie(types.values, labels=types.index, labeldistance=1.3, autopct= '%1.f%%', shadow= True, startangle=60 )
plt.title('role of players', fontsize=15)
plt.plot()
# Out:
# []

# %%
ipl
# Out:
#                      Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0               Rashid Khan  Draft Pick       BOWLER             15.0
# 1             Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           Lockie Ferguson        2 Cr       BOWLER             10.0
# 3             Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4              Shubman Gill  Draft Pick       BATTER              8.0
# ..                      ...         ...          ...              ...
# 628            Sairaj Patil     20 Lakh       BATTER              0.0
# 629              Monu Singh     20 Lakh       BOWLER              0.0
# 630  Nivethan Radhakrishnan     20 Lakh       BOWLER              0.0
# 631            Lance Morris     20 Lakh       BOWLER              0.0
# 632            Aaron Hardie     20 Lakh  ALL-ROUNDER              0.0
#
#      Cost IN $ (000)       2021 Squad            Team  Status
# 0             1950.0              SRH  Gujarat Titans    sold
# 1             1950.0               MI  Gujarat Titans    sold
# 2             1300.0              KKR  Gujarat Titans    sold
# 3             1170.0               RR  Gujarat Titans    sold
# 4             1040.0              KKR  Gujarat Titans    sold
# ..               ...              ...             ...     ...
# 628              0.0  Not Participate          Unsold  Unsold
# 629              0.0  Not Participate          Unsold  Unsold
# 630              0.0  Not Participate          Unsold  Unsold
# 631              0.0  Not Participate          Unsold  Unsold
# 632              0.0  Not Participate          Unsold  Unsold
#
# [633 rows x 8 columns]

# %%
#Players sold and unsold usingabar graph.
plt.figure(figsize=(10,5))
fig=sns.countplot(ipl['Status'],palette=['Green','Red'])
plt.xlabel('Sold or Unsold')
plt.ylabel('Number of Players')
plt.title('Sold vs Unsold',fontsize=15)
plt.plot()
for p in fig.patches:
    fig.annotate(format(p.get_height(),'.0f'),( p.get_x() +
    p.get_width()/2.,p.get_height()),ha='center',va='center',
    xytext=(0,4),textcoords='offset points')

# %%
ipl.groupby('Status')['Player'].count()
# Out:
# Status
# Unsold    396
# sold      237
# Name: Player, dtype: int64

# %%
#Total number of players bought by each team.

plt.figure(figsize=(20, 10))
fig=sns.countplot(ipl[ipl['Team']!='Unsold']['Team' ])
plt.xlabel('Team Names')
plt.ylabel('Number of Players')
plt.title('Players Bought by Each Team', fontsize=12)
plt.xticks(rotation=70)
plt.plot()
                                                                 

for p in fig.patches:
    fig.annotate(format(p.get_height(),'.0f'),( p.get_x() +
    p.get_width()/2.,p.get_height()),ha='center',va='center',
    xytext=(0,4),textcoords='offset points')

# %%
ipl['retention']=ipl['Base Price']

# %%
ipl
# Out:
#                      Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0               Rashid Khan  Draft Pick       BOWLER             15.0
# 1             Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           Lockie Ferguson        2 Cr       BOWLER             10.0
# 3             Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4              Shubman Gill  Draft Pick       BATTER              8.0
# ..                      ...         ...          ...              ...
# 628            Sairaj Patil     20 Lakh       BATTER              0.0
# 629              Monu Singh     20 Lakh       BOWLER              0.0
# 630  Nivethan Radhakrishnan     20 Lakh       BOWLER              0.0
# 631            Lance Morris     20 Lakh       BOWLER              0.0
# 632            Aaron Hardie     20 Lakh  ALL-ROUNDER              0.0
#
#      Cost IN $ (000)       2021 Squad            Team  Status   retention
# 0             1950.0              SRH  Gujarat Titans    sold  Draft Pick
# 1             1950.0               MI  Gujarat Titans    sold  Draft Pick
# 2             1300.0              KKR  Gujarat Titans    sold        2 Cr
# 3             1170.0               RR  Gujarat Titans    sold     40 Lakh
# 4             1040.0              KKR  Gujarat Titans    sold  Draft Pick
# ..               ...              ...             ...     ...         ...
# 628              0.0  Not Participate          Unsold  Unsold     20 Lakh
# 629              0.0  Not Participate          Unsold  Unsold     20 Lakh
# 630              0.0  Not Participate          Unsold  Unsold     20 Lakh
# 631              0.0  Not Participate          Unsold  Unsold     20 Lakh
# 632              0.0  Not Participate          Unsold  Unsold     20 Lakh
#
# [633 rows x 9 columns]

# %%
ipl['retention'].replace(['2 Cr','40 Lakh','20 Lakh','1 Cr','75 Lakh',
        '50 Lakh','30 Lakh','1.5 Cr'],'From Auction',inplace=True)

# %%
ipl
# Out:
#                      Player  Base Price         TYPE  COST IN ₹ (CR.)  \
# 0               Rashid Khan  Draft Pick       BOWLER             15.0
# 1             Hardik Pandya  Draft Pick  ALL-ROUNDER             15.0
# 2           Lockie Ferguson        2 Cr       BOWLER             10.0
# 3             Rahul Tewatia     40 Lakh  ALL-ROUNDER              9.0
# 4              Shubman Gill  Draft Pick       BATTER              8.0
# ..                      ...         ...          ...              ...
# 628            Sairaj Patil     20 Lakh       BATTER              0.0
# 629              Monu Singh     20 Lakh       BOWLER              0.0
# 630  Nivethan Radhakrishnan     20 Lakh       BOWLER              0.0
# 631            Lance Morris     20 Lakh       BOWLER              0.0
# 632            Aaron Hardie     20 Lakh  ALL-ROUNDER              0.0
#
#      Cost IN $ (000)       2021 Squad            Team  Status     retention
# 0             1950.0              SRH  Gujarat Titans    sold    Draft Pick
# 1             1950.0               MI  Gujarat Titans    sold    Draft Pick
# 2             1300.0              KKR  Gujarat Titans    sold  From Auction
# 3             1170.0               RR  Gujarat Titans    sold  From Auction
# 4             1040.0              KKR  Gujarat Titans    sold    Draft Pick
# ..               ...              ...             ...     ...           ...
# 628              0.0  Not Participate          Unsold  Unsold  From Auction
# 629              0.0  Not Participate          Unsold  Unsold  From Auction
# 630              0.0  Not Participate          Unsold  Unsold  From Auction
# 631              0.0  Not Participate          Unsold  Unsold  From Auction
# 632              0.0  Not Participate          Unsold  Unsold  From Auction
#
# [633 rows x 9 columns]

# %%
#Treating Base Price
ipl['Base Price'].replace( 'Draft Pick',0, inplace=True)

# %%
ipl
# Out:
#                      Player Base Price         TYPE  COST IN ₹ (CR.)  \
# 0               Rashid Khan          0       BOWLER             15.0
# 1             Hardik Pandya          0  ALL-ROUNDER             15.0
# 2           Lockie Ferguson       2 Cr       BOWLER             10.0
# 3             Rahul Tewatia    40 Lakh  ALL-ROUNDER              9.0
# 4              Shubman Gill          0       BATTER              8.0
# ..                      ...        ...          ...              ...
# 628            Sairaj Patil    20 Lakh       BATTER              0.0
# 629              Monu Singh    20 Lakh       BOWLER              0.0
# 630  Nivethan Radhakrishnan    20 Lakh       BOWLER              0.0
# 631            Lance Morris    20 Lakh       BOWLER              0.0
# 632            Aaron Hardie    20 Lakh  ALL-ROUNDER              0.0
#
#      Cost IN $ (000)       2021 Squad            Team  Status     retention
# 0             1950.0              SRH  Gujarat Titans    sold    Draft Pick
# 1             1950.0               MI  Gujarat Titans    sold    Draft Pick
# 2             1300.0              KKR  Gujarat Titans    sold  From Auction
# 3             1170.0               RR  Gujarat Titans    sold  From Auction
# 4             1040.0              KKR  Gujarat Titans    sold    Draft Pick
# ..               ...              ...             ...     ...           ...
# 628              0.0  Not Participate          Unsold  Unsold  From Auction
# 629              0.0  Not Participate          Unsold  Unsold  From Auction
# 630              0.0  Not Participate          Unsold  Unsold  From Auction
# 631              0.0  Not Participate          Unsold  Unsold  From Auction
# 632              0.0  Not Participate          Unsold  Unsold  From Auction
#
# [633 rows x 9 columns]
